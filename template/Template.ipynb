# %%
# Lab settings - please ingnore
options(repr.plot.width=7, repr.plot.height=3.5) # Make plots a resonable size

# %% [markdown]
# <div class="big_title">LAB #: Title</div>
#
# BIO3782: Biologist's Toolkit (Dalhousie University)
#
# ----------------------------------------

# %% [markdown]
# # Setup of workspace
#
# <span class="important"></span> Make sure all required files are in the working directory:
#
# * Create a **folder** on the "Desktop" and name it <span class='file'>Lab6</span>
# * From Brightspace, download the following files into your new folder <span class='file'>Desktop\Lab6</span>:
#    * <span class='file'>model_NPZD2_SHELLE.py</span>
#
# * In Spyder, change the "working directory" to: <span class='file'>Desktop\Lab6</span>. Note that to change the "working directory", click on "folder icon" on top-right corner.
#
# ----------------------------------

# %% [markdown]
# <div class="Q"><br>
#
# Question goes here.
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# `functions` and other `objects` are styled using "backticks"    <br>
# ----------------------------- <br>
# <span class="console"></span> <br>
# ----------------------------- <br>
# <span class="editor"></span> <br>
# ----------------------------- <br>
# <span class="c2c"></span> <br>
# <div class="c2c"></div> <br>
# ----------------------------- <br>
# <span class="source"></span> <br>
# ----------------------------- <br>
# <span class="run"></span> <br>
# <div class="run"></div> <br>
# ----------------------------- <br>
# <span class="runcell"></span> <br>
# <div class="runcell"></div> <br>
# ----------------------------- <br>
# <span class="file">filename.r</span> <br>
# <div class="file">filename.r</div> <br>
# ----------------------------- <br>
# <span class="important"></span> Text goes here <br>
# <div class="important">Text goes here</div> <br>
# ----------------------------- <br>
# <span class="note"></span> Text goes here <br>
# <div class="note">Text goes here</div> <br>
# ----------------------------- <br>
# <span class="checkpoint">Text</span> <br>
# <div class="checkpoint">checkpoint</div> <br>
# -----------------------------<br>
# <span class="codeerror">Text</span> <br>
# <div class="codeerror">Text codeerror</div> <br>
# ----------------------------- <br>
# <span class="lineerror">Text</span> <br>
# <div class="lineerror">Text Lineeror</div> <br>
# ----------------------------- <br>
# <span class="terminal">Text goes here</span> <br>
# <div class="terminal">Text goes here</div> <br>
# ----------------------------- <br>
# <span class="terminalBlock">Text</span> <br>
# <div class="terminalBlock">Text</div> <br>
# ----------------------------- <br>
# <span class="nomenclature">nomenclature</span> <br>
# <div class="nomenclature">nomenclature</div> <br>
# ----------------------------- <br>
# <span class="code">code</span> <br>
# <div class="code">code</div> <br>
# ----------------------------- <br>
# <span class="rendered_html">rendered_html</span> <br>
# <div class="rendered_html">rendered_html</div> <br>
# ----------------------------- <br>
# <span class="console"></span>
#
# <br>
# <div class="use_console"></div>
#
# <br>
# <div class="use_editor"></div>
#
#
#
# <br><br><br>
# <div class="startTASK"></div>
#
# Tasxk text goes here
#
# <div class="endTASK"></div>
# <br><br><br>
#
#
# Normal image
# <img src="../media/R_logo.png" width="150px">
#
# -------------
#
# Click Image to display larger image
# <a href="../media/R_logo.png" target="_blank"><img src="../media/R_logo.png" width="150px"></a>

# %% [markdown]
# <div class="big_title">This is the end of lab</div>
#
# *******************
# *******************
#
# Code below is for formatting of this lab. Do not alter!

# %%
cssFile <- '../css/custom.css'
IRdisplay::display_html(readChar(cssFile, file.info(cssFile)$size))

IRdisplay::display_html("<style>.Q::before {counter-increment: question_num;
    content: 'QUESTION ' counter(question_num) ': '; white-space: pre; }.T::before {counter-increment: task_num;
    content: 'Task ' counter(task_num) ': ';</style>")
# Out:
# <style>
#
# body {
#   counter-reset: question_num task_num;                     /* Set a counter named 'section', and it`s initial value is 0. */
# }
#
# /* Question Box */
# .Q {
#     background-color:#ff9900;
#     color:black;
#     font-size:17px;
#     width:100%;
#     border:1px solid #666666;
#     padding:5px;
# }
#
# .Q::before {
#     counter-increment: question_num;
#     content: "QUESTION " counter(question_num) '\A';
#     white-space: pre;
# }
#
#
# /* Question Box */
# .T {
#     background-color:#00F7FF;
#     color:black;
#     font-size:17px;
#     font-weight: bold;
#     width:10%;
#     padding:5px;
# }
#
#
# .T::before {
#     counter-increment: task_num;
#     content: "Task " counter(task_num) ': ';
# }
#
#
# /* TASK BOX */
# .startTASK {
#     background: linear-gradient(to bottom, #b3ffb3 0%, #ffffff 100%);
#     border-top-left-radius: 10px;
#     border-top-right-radius: 10px;
#     border:1px solid #009900;
#     border-bottom:1px solid #ffffff;
#     color:#006600;
#     font-size:17px;
#     width:100%;
#     font-weight: bold;
#     padding:5px;
#     padding-top:15px;
# }
# .startTASK::before {
#     counter-increment: task_num;
#     content: "Task " counter(task_num) ': ';
# }
#
# .endTASK {
#     background: linear-gradient(to bottom, #ffffff 0%, #b3ffb3 100%);
#     border-bottom-left-radius: 10px;
#     border-bottom-right-radius: 10px;
#     border:1px solid #009900;
#     border-top:1px solid #ffffff;
#     color:#006600;
#     font-size:13px;
#     width:100%;
#     font-weight: bold;
#     padding:5px;
#     padding-top:15px;
# }
# .endTASK::before {
#     content: "End of Task";
# }
#
#
#
#
#
#
# /* Use Editor */
# .use_editor {
#     background: linear-gradient(to right, #ccffcc 0%, #ffffff 100%);
#     border-top-left-radius: 10px;
#     border-top-right-radius: 10px;
#     border:1px solid #ffffff;
#     border-bottom:1px solid #ffffff;
#     color:#66cc66;
#     font-size:10px;
#     width:100%;
#     padding:0px;
#     padding-bottom:3px;
#     padding-left:7px;
#     margin-left: -5px;
#     margin-right: 150px;
#     margin-bottom: -13px;
# }
# .use_editor::before {
#     content: "Type in EDITOR, hightlight, and click RUN";
#     }
#
#
# /* Use Console */
# .use_console {
#     background: linear-gradient(to right, #ffe6e6 0%, #ffffff 100%);
#     border-top-left-radius: 10px;
#     border-top-right-radius: 10px;
#     border:1px solid #ffffff;
#     border-bottom:1px solid #ffffff;
#     color:#ff9999;
#     font-size:10px;
#     width:100%;
#     padding:0px;
#     padding-bottom:3px;
#     padding-left:7px;
#     margin-left: -5px;
#     margin-right: 150px;
#     margin-bottom: -13px;
# }
# .use_console::before {
#     content: "Type in CONSOLE and click ENTER";
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
# .qhelp {
#     color:#666666;
#     font-size:15px
# }
#
# .qhelp::after {
#     content: "Answer this question in the corresponding Brightspace LAB quiz"
# }
#
#
#
# /* code */
# .rendered_html pre, .rendered_html code {
#     font-family: "SF Mono","Segoe UI Mono","Roboto Mono","Ubuntu Mono",Menlo,Courier,monospace;
#     padding: 1px 3px;
#     border: 1px solid #e6e6e6;
#     border-radius: 3px;
#     background: #e6e6e6;
#     font-size: 12px;
#     line-height: 1.4;
#     color: #0052CC;
# }
#
#
# /* Console */
# .console {
#     background-color:#d2d2d2;
#     color:#FF2525;
#     font-size:12px;
#     line-height: 1.4;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
# }
# .console::before {
#     content: "Console";
# }
#
# /* Editor */
# .editor {
#     background-color:#d2d2d2;
#     color:#00b300;
#     font-size: 12px;
#     line-height: 1.4;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
# }
# .editor::before {
#     content: "Editor";
# }
#
#
#
# /* Copy to CONSOLE */
# .c2c {
#     background-color:#d2d2d2;
#     color:#ff8080;
#     font-size:13px;
#     border:1px solid #bfbfbf;
#     padding:1px 3px;
#     border-radius: 3px;
#     margin-top: 10px;
#     display: inline-block;
# }
#
# .c2c::before {
#     content: "Copy-paste into Spyder's Console";
# }
#
# /* Type in CONSOLE */
# .t2c {
#     background-color:#d2d2d2;
#     color:#ff8080;
#     font-size:13px;
#     border:1px solid #bfbfbf;
#     padding:1px 3px;
#     border-radius: 3px;
#     margin-top: 10px;
#     display: inline-block;
# }
#
# .t2c::before {
#     content: "Type into Spyder's Console";
# }
#
#
# /* SOURCE */
# .source {
#     background-color:#d2d2d2;
#     color:#009EBF;
#     font-size: 12px;
#     line-height: 1.4;
#     font-weight: bold;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
# }
# .source::before {
#     content: "\25B6" "Source";
# }
#
#
# /* RUN */
# .run {
#     background-color:#d2d2d2;
#     color:#00b300;
#     font-size: 12px;
#     line-height: 1.4;
#     font-weight: bold;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
# }
# .run::before {
#     content: "\25B6" "RUN";
# }
#
# /* RUN */
# .runcell {
#     background-color:#d2d2d2;
#     color:#00b300;
#     font-size: 12px;
#     line-height: 1.4;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
# }
# .runcell::before {
#     content: "RUN current cell";
# }
#
# /* FILE */
# .file {
#     color:#b36b00;
#     font-size: 12px;
#     line-height: 1.4;
#     font-weight: bold;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
# }
#
# /* important */
# .important {
#     background-color:#ff4d4d;
#     color:black;
#     font-size: 13px;
#     line-height: 1.4;
#     font-weight: bold;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
#     margin-top:5px;
# }
# .important::before {
#     content: "Important:";
# }
#
# /* important */
# .note {
#     background-color:#ffff80;
#     color:black;
#     font-size: 13px;
#     line-height: 1.4;
#     font-weight: bold;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
#     margin-top:5px;
# }
# .note::before {
#     content: "Note:";
# }
#
#
# /* TODO */
# .TODO {
#     background-color:red;
#     color:black;
#     font-size:18px;
#     width:100%;
#     padding:10px;
# }
# .TODO::before {
#     content: "TO-DO:";
# }
#
#
# .nomenclature {
#     font-family: "SF Mono","Segoe UI Mono","Roboto Mono","Ubuntu Mono",Menlo,Courier,monospace;
#     background-color:#ffff80;
#     color:black;
#     font-size: 15px;
#     line-height: 1.4;
#     font-weight: bold;
#     border:1px solid #bfbfbf;
#     padding-left:3px;
#     padding-right:3px;
#     display: inline-block;
#     margin-top:3px;
# }
#
#
#
# .big_title {
#     background-color:#cccccc;
#     color:black;
#     font-size: 35px;
#     line-height: 1.4;
#     font-weight: bold;
#     border:1px solid #8c8c8c;
#     padding:20px;
#     margin-top:5px;
#     width:100%;
# }
#
#
# .codeX {
#     font-family: "SF Mono","Segoe UI Mono","Roboto Mono","Ubuntu Mono",Menlo,Courier,monospace;
#     background-color:#e6e6e6;
#     color:#0066ff;
#     font-size: 13px;
#     line-height: 1.4;
#     padding:2px;
#     display: inline-block;
# }
#
#
#
# /* checkpoint */
# .checkpoint {
#     background-color:yellow;
#     color:blue;
#     font-size: 15px;
#     line-height: 1.4;
#     font-weight: bold;
#     border:1px solid #bfbfbf;
#     padding-top:0px;
#     padding-bottom:0px;
#     padding-left:3px;
#     padding-right:3px;
#     border-radius: 3px;
#     display: inline-block;
#     margin-top:5px;
# }
#
# .codeerror {
#     background-color:#ffb3b3;
#     color:red;
#     font-size: 13px;
#     line-height: 1.4;
#     border:1px solid #ffb3b3;
#     padding-top:7px;
#     padding-bottom:7px;
#     padding-left:7px;
#     padding-right:7px;
#     border-radius: 3px;
#     margin:20px;
#     margin-left:25px;
# }
#
# .lineerror {
#     background-colo
# <style>.Q::before {counter-increment: question_num;
#     content: 'QUESTION ' counter(question_num) ': '; white-space: pre; }.T::before {counter-increment: task_num;
#     content: 'Task ' counter(task_num) ': ';</style>
